# %% [markdown]
# # Data Analysis

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# import First CSV file
df1=pd.read_csv('imbdfilm_I.csv')
df1
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                                    The Dark Knight            152
# 1         2      The Lord of the Rings: The Return of the King            201
# 2         3                Spider-Man: Across the Spider-Verse            140
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1767   1768                                              Radhe            109
# 1768   1769                                             Race 3            160
# 1769   1770                                  Angels Apocalypse             85
# 1770   1771                                           Elk*rtuk            125
# 1771   1772                                            Sadak 2            133
#
# ...

# %%
# drop unuseful columns
df1.drop(['Director1','Director2','Director3','Director4','Director5','Director6'],axis=1,inplace=True)
df1
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                                    The Dark Knight            152
# 1         2      The Lord of the Rings: The Return of the King            201
# 2         3                Spider-Man: Across the Spider-Verse            140
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1767   1768                                              Radhe            109
# 1768   1769                                             Race 3            160
# 1769   1770                                  Angels Apocalypse             85
# 1770   1771                                           Elk*rtuk            125
# 1771   1772                                            Sadak 2            133
#
# ...

# %%
df1.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director'],
#       dtype='object')

# %%
# import second csv file
df2=pd.read_csv('imbdfilm_II.csv')
df2
# Out:
#                                              Movie Name    Votes  \
# 0                                       The Dark Knight  2746315
# 1         The Lord of the Rings: The Return of the King  1901024
# 2                   Spider-Man: Across the Spider-Verse   191053
# 3                                             Inception  2437301
# 4     The Lord of the Rings: The Fellowship of the Ring  1929399
# ...                                                 ...      ...
# 1767                                              Radhe   179074
# 1768                                             Race 3    47832
# 1769                                  Angels Apocalypse    42919
# 1770                                           Elk*rtuk    39604
# 1771                                            Sadak 2    96364
#
#                                Genre  Gross_Collection in USD(Million)  \
# 0             Action/ Crime/ Drama                              534.86
# ...

# %%
# drop unuseful columns
df2.drop(['Star1','Star2','Star3','Star4','Genre1','Genre2','Genre3'],axis=1,inplace=True)
df2
# Out:
#                                              Movie Name    Votes  \
# 0                                       The Dark Knight  2746315
# 1         The Lord of the Rings: The Return of the King  1901024
# 2                   Spider-Man: Across the Spider-Verse   191053
# 3                                             Inception  2437301
# 4     The Lord of the Rings: The Fellowship of the Ring  1929399
# ...                                                 ...      ...
# 1767                                              Radhe   179074
# 1768                                             Race 3    47832
# 1769                                  Angels Apocalypse    42919
# 1770                                           Elk*rtuk    39604
# 1771                                            Sadak 2    96364
#
#                                Genre  Gross_Collection in USD(Million)  \
# 0             Action/ Crime/ Drama                              534.86
# ...

# %%
# merge two dataframe
df3=pd.concat([df1,df2],axis=1)

# %%
df3
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                                    The Dark Knight            152
# 1         2      The Lord of the Rings: The Return of the King            201
# 2         3                Spider-Man: Across the Spider-Verse            140
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1767   1768                                              Radhe            109
# 1768   1769                                             Race 3            160
# 1769   1770                                  Angels Apocalypse             85
# 1770   1771                                           Elk*rtuk            125
# 1771   1772                                            Sadak 2            133
#
# ...

# %%
df3.shape
# Out:
# (1772, 14)

# %%
df3.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director', 'Movie Name', 'Votes', 'Genre',
#        'Gross_Collection in USD(Million)', 'Certificate', 'Stars',
#        'Popularity'],
#       dtype='object')

# %%
# drop 1 column as per condition
df3.drop(['Movie Name'],axis=1,inplace=True)
df3
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                                    The Dark Knight            152
# 1         2      The Lord of the Rings: The Return of the King            201
# 2         3                Spider-Man: Across the Spider-Verse            140
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1767   1768                                              Radhe            109
# 1768   1769                                             Race 3            160
# 1769   1770                                  Angels Apocalypse             85
# 1770   1771                                           Elk*rtuk            125
# 1771   1772                                            Sadak 2            133
#
# ...

# %%
df3.head()
# Out:
#    Sl No                                        Movie Name1  Time Duration  \
# 0      1                                    The Dark Knight            152
# 1      2      The Lord of the Rings: The Return of the King            201
# 2      3                Spider-Man: Across the Spider-Verse            140
# 3      4                                          Inception            148
# 4      5  The Lord of the Rings: The Fellowship of the Ring            178
#
#    Year  Ratings  Metascore  \
# 0  2008      9.0         84
# 1  2003      9.0         94
# 2  2023      8.9         86
# 3  2010      8.8         74
# 4  2001      8.8         92
#
#                                             Director    Votes  \
# 0                                  Christopher Nolan  2746315
# 1                                      Peter Jackson  1901024
# 2  sJoaquim Dos Santos/ Kemp Powers/ Justin K. Th...   191053
# 3                                  Christopher Nolan  2437301
# ...

# %%
df3.shape
# Out:
# (1772, 13)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1772 entries, 0 to 1771
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Sl No                             1772 non-null   int64
#  1   Movie Name1                       1772 non-null   object
#  2   Time Duration                     1772 non-null   int64
#  3   Year                              1772 non-null   int64
#  4   Ratings                           1772 non-null   float64
#  5   Metascore                         1772 non-null   int64
#  6   Director                          1772 non-null   object
#  7   Votes                             1772 non-null   int64
#  8   Genre                             1772 non-null   object
#  9   Gross_Collection in USD(Million)  1772 non-null   float64
#  10  Certificate                       1772 non-null   object
# ...

# %%
# check datatypes
df3.dtypes
# Out:
# Sl No                                 int64
# Movie Name1                          object
# Time Duration                         int64
# Year                                  int64
# Ratings                             float64
# Metascore                             int64
# Director                             object
# Votes                                 int64
# Genre                                object
# Gross_Collection in USD(Million)    float64
# Certificate                          object
# Stars                                object
# Popularity                          float64
# dtype: object

# %%
# check null values
df3.isnull().sum()
# Out:
# Sl No                               0
# Movie Name1                         0
# Time Duration                       0
# Year                                0
# Ratings                             0
# Metascore                           0
# Director                            0
# Votes                               0
# Genre                               0
# Gross_Collection in USD(Million)    0
# Certificate                         0
# Stars                               0
# Popularity                          0
# dtype: int64

# %%
# check nunique values
df3.nunique()
# Out:
# Sl No                               1772
# Movie Name1                         1741
# Time Duration                        119
# Year                                  74
# Ratings                               67
# Metascore                             87
# Director                             962
# Votes                               1764
# Genre                                 81
# Gross_Collection in USD(Million)    1362
# Certificate                           23
# Stars                               1751
# Popularity                            67
# dtype: int64

# %%
df3_class=df3.copy()

# %% [markdown]
# # EDA Analysis

# %%
sns.heatmap(df3.isnull())
plt.show()

# %%
percentage_missing=df3.isnull().sum()*100/len(df3)
print(percentage_missing)
# Out:
# Sl No                               0.0
# Movie Name1                         0.0
# Time Duration                       0.0
# Year                                0.0
# Ratings                             0.0
# Metascore                           0.0
# Director                            0.0
# Votes                               0.0
# Genre                               0.0
# Gross_Collection in USD(Million)    0.0
# Certificate                         0.0
# Stars                               0.0
# Popularity                          0.0
# dtype: float64

# %%
plt.figure(figsize=(9,15))
sns.pairplot(df3)

# %%
sns.countplot(df3['Year'],color='b')
plt.show()

# %% [markdown]
# # Data (Preparation)

# %%
df3.corr()
# Out:
#                                      Sl No  Time Duration      Year   Ratings  \
# Sl No                             1.000000      -0.370954  0.143485 -0.940153
# Time Duration                    -0.370954       1.000000  0.134565  0.340778
# Year                              0.143485       0.134565  1.000000 -0.140907
# Ratings                          -0.940153       0.340778 -0.140907  1.000000
# Metascore                        -0.433966       0.013941 -0.149150  0.433488
# Votes                            -0.429487       0.278485  0.053961  0.421908
# Gross_Collection in USD(Million) -0.244956       0.240202  0.059055  0.235491
# Popularity                       -0.940153       0.340778 -0.140907  1.000000
#
#                                   Metascore     Votes  \
# Sl No                             -0.433966 -0.429487
# Time Duration                      0.013941  0.278485
# Year                              -0.149150  0.053961
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df3.corr(),annot=True,linewidth=4,linecolor='blue')
plt.show()

# %%
df3.dropna(axis=0)
# Out:
#       Sl No                                        Movie Name1  Time Duration  \
# 0         1                                    The Dark Knight            152
# 1         2      The Lord of the Rings: The Return of the King            201
# 2         3                Spider-Man: Across the Spider-Verse            140
# 3         4                                          Inception            148
# 4         5  The Lord of the Rings: The Fellowship of the Ring            178
# ...     ...                                                ...            ...
# 1767   1768                                              Radhe            109
# 1768   1769                                             Race 3            160
# 1769   1770                                  Angels Apocalypse             85
# 1770   1771                                           Elk*rtuk            125
# 1771   1772                                            Sadak 2            133
#
# ...

# %%
duplicate_data=df3.duplicated().any()
print(duplicate_data)
# Out:
# False

# %%
df3.describe()
# Out:
#              Sl No  Time Duration         Year      Ratings    Metascore  \
# count  1772.000000    1772.000000  1772.000000  1772.000000  1772.000000
# mean    886.500000     115.406321  2006.191309     6.479684    47.722912
# std     511.676656      21.745246    13.309421     0.999093    22.505322
# min       1.000000      45.000000  1924.000000     1.200000     0.000000
# 25%     443.750000     100.000000  2000.000000     5.900000    37.000000
# 50%     886.500000     112.000000  2009.000000     6.500000    50.000000
# 75%    1329.250000     127.000000  2016.000000     7.100000    64.000000
# max    1772.000000     321.000000  2023.000000     9.000000    98.000000
#
#               Votes  Gross_Collection in USD(Million)   Popularity
# count  1.772000e+03                       1772.000000  1772.000000
# mean   1.809427e+05                         64.102314     6.479684
# std    2.374598e+05                         98.179894     0.999093
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(round(df3.describe()[1:].transpose(),2),annot=True,fmt='.2f',linecolor='b',linewidth=4)
plt.show()

# %%
df3.columns
# Out:
# Index(['Sl No', 'Movie Name1', 'Time Duration', 'Year', 'Ratings', 'Metascore',
#        'Director', 'Votes', 'Genre', 'Gross_Collection in USD(Million)',
#        'Certificate', 'Stars', 'Popularity'],
#       dtype='object')

# %%
df3[df3['Time Duration']>=180]['Movie Name1']
# Out:
# 1           The Lord of the Rings: The Return of the King
# 11                                   Shichinin no samurai
# 19                                      Avengers: Endgame
# 47                                     Gangs of Wasseypur
# 74                                                 Sholay
# 104                                           Arjun Reddy
# 107                          Zack Snyder's Justice League
# 137                                RRR (Rise Roar Revolt)
# 201                              Avatar: The Way of Water
# 268                          It's a Mad Mad Mad Mad World
# 269                                            Grindhouse
# 287                                          Jodhaa Akbar
# 372                                               Ghajini
# 389                                             King Kong
# 395     Batman v Superman: Dawn of Justice (Ultimate E...
# 732                                            Wyatt Earp
# ...

# %%
df3.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 1977    523632.000000
# 1980    347032.200000
# 1959    336664.000000
# 1999    253827.227273
# 2003    250326.541667
#             ...
# 1975     38034.666667
# 1953     37373.000000
# 1949     34542.000000
# 1966     32220.000000
# 1932     29265.000000
# Name: Votes, Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Votes',data=df3)
plt.title("Average votes by year")
plt.show()

# %%
df3.groupby('Year')['Gross_Collection in USD(Million)'].mean().sort_values(ascending=False)
# Out:
# Year
# 1977    165.426667
# 1980     94.510000
# 1983     93.744286
# 2017     90.250806
# 1999     88.664545
#            ...
# 1958      0.000000
# 1949      0.000000
# 1948      0.000000
# 1932      0.000000
# 2023      0.000000
# Name: Gross_Collection in USD(Million), Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Gross_Collection in USD(Million)',data=df3)
plt.title("Average Gross_Collection in USD(Million) by year")
plt.show()

# %%
df3.groupby('Year')['Ratings'].mean().sort_values(ascending=False)
# Out:
# Year
# 1959    8.300000
# 1924    8.200000
# 1949    8.100000
# 1958    8.100000
# 1926    8.100000
#           ...
# 2003    6.266667
# 1996    6.204000
# 2005    6.190698
# 1997    6.181579
# 2020    6.150000
# Name: Ratings, Length: 74, dtype: float64

# %%
plt.figure(figsize=(35,18))
sns.barplot(x='Year',y='Ratings',data=df3)
plt.title("Average Ratings by year")
plt.show()

# %%
df3.groupby('Director')['Ratings'].mean().sort_values()
# Out:
# Director
# Mahesh Bhatt                                            1.20
# Keith English                                           1.50
# sSean Cain/ Enzo Zelocchi                               1.60
# Remo D'Souza                                            1.90
# Marcelo Grion                                           2.40
#                                                         ...
# Peter Jackson                                           8.45
# Hanu Raghavapudi                                        8.60
# Masaki Kobayashi                                        8.60
# Sudha Kongara                                           8.70
# sJoaquim Dos Santos/ Kemp Powers/ Justin K. Thompson    8.90
# Name: Ratings, Length: 962, dtype: float64

# %%
df3['Year'].value_counts()
# Out:
# 2016    78
# 2014    78
# 2018    71
# 2011    69
# 2013    68
#         ..
# 1959     1
# 1948     1
# 1932     1
# 1938     1
# 1965     1
# Name: Year, Length: 74, dtype: int64

# %%
plt.figure(figsize=(35,18))
sns.countplot(x='Year',data=df3)
plt.show()

# %%
df3['Gross_Collection in USD(Million)'].max()
# Out:
# 936.66

# %%
df3[df3['Gross_Collection in USD(Million)'].max()==df3['Gross_Collection in USD(Million)']]['Movie Name1']
# Out:
# 142    Star Wars: Episode VII - The Force Awakens
# Name: Movie Name1, dtype: object

# %%
df3['Votes'].max()
# Out:
# 2746315

# %%
df3[df3['Votes'].max()==df3['Votes']]['Movie Name1']
# Out:
# 0    The Dark Knight
# Name: Movie Name1, dtype: object

# %%
df3.drop(["Popularity","Certificate"],axis=1,inplace=True)
df3.sample()
# Out:
#      Sl No                                 Movie Name1  Time Duration  Year  \
# 303    304  Pirates of the Caribbean: Dead Man's Chest            151  2006
#
#      Ratings  Metascore        Director   Votes                         Genre  \
# 303      7.4         53  Gore Verbinski  741842  Action/ Adventure/ Fantasy
#
#      Gross_Collection in USD(Million)  \
# 303                            423.32
#
#                                                  Stars
# 303  Johnny Depp/ Orlando Bloom/ Keira Knightley/ J...

# %% [markdown]
# # Using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le=LabelEncoder
code=["Movie Name1","Director","Genre","Stars"]
for p in code:
    Le=LabelEncoder()
    Le.fit(df3[p])
    df3[p]=Le.fit_transform(df3[p])
df3
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 0         1         1332            152  2008      9.0         84       136
# 1         2         1437            201  2003      9.0         94       617
# 2         3         1179            140  2023      8.9         86       920
# 3         4          614            148  2010      8.8         74       136
# 4         5         1436            178  2001      8.8         92       617
# ...     ...          ...            ...   ...      ...        ...       ...
# 1767   1768          999            109  2021      1.9          0       635
# 1768   1769          997            160  2018      1.9          0       655
# 1769   1770           87             85  2015      1.6          0       954
# 1770   1771          400            125  2021      1.5          0       449
# 1771   1772         1075            133  2020      1.2          0       495
#
# ...

# %% [markdown]
# Using Z Score

# %%
from scipy.stats import zscore
z=np.abs(zscore(df3))
z
# Out:
#          Sl No  Movie Name1  Time Duration      Year   Ratings  Metascore  \
# 0     1.731074     0.916559       1.683311  0.135934  2.523316   1.612389
# 1     1.729119     1.125444       3.937313  0.239846  2.523316   2.056854
# 2     1.727164     0.612185       1.131310  1.263273  2.423197   1.701282
# 3     1.725209     0.511813       1.499311  0.286246  2.323078   1.167924
# 4     1.723254     1.123454       2.879312  0.390158  2.323078   1.967961
# ...        ...          ...            ...       ...       ...        ...
# 1767  1.723254     0.254097       0.294691  1.112961  4.585136   2.121115
# 1768  1.725209     0.250118       2.051311  0.887493  4.585136   2.121115
# 1769  1.727164     1.560214       1.398692  0.662026  4.885493   2.121115
# 1770  1.729119     0.937540       0.441310  1.112961  4.985612   2.121115
# 1771  1.731074     0.405289       0.809310  1.037805  5.285969   2.121115
#
#       Director      Votes     Genre  Gross_Collection in USD(Million)  \
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    0,    1,    1,    1,    3,    4,    5,    6,    7,    9,
#          10,   11,   11,   12,   14,   15,   16,   18,   18,   19,   19,
#          19,   22,   22,   25,   27,   29,   37,   37,   38,   39,   41,
#          42,   43,   47,   48,   52,   52,   57,   58,   69,   71,   72,
#          74,   83,   84,   84,   86,   86,   97,  104,  107,  108,  108,
#         111,  119,  125,  131,  137,  138,  142,  142,  147,  179,  187,
#         188,  195,  196,  201,  201,  204,  218,  220,  253,  268,  268,
#         269,  272,  273,  287,  294,  300,  303,  304,  307,  334,  337,
#         355,  368,  372,  377,  377,  389,  395,  400,  418,  442,  551,
#         569,  573,  575,  589,  601,  630,  680,  732,  846,  849,  911,
#        1084, 1182, 1322, 1480, 1753, 1754, 1755, 1756, 1757, 1758, 1759,
#        1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770,
# ...

# %%
df3_new=df3[(z<3).all(axis=1)]
print("original shape=",df3.shape)
print("new shape=",df3_new.shape)
# Out:
# original shape= (1772, 11)
# new shape= (1656, 11)

# %%
print("percentage loss=",((1775-1660)/1775)*100)
# Out:
# percentage loss= 6.478873239436619

# %%
df3.skew()
# Out:
# Sl No                               0.000000
# Movie Name1                        -0.002415
# Time Duration                       1.483571
# Year                               -1.499812
# Ratings                            -0.802183
# Metascore                          -0.630108
# Director                           -0.063005
# Votes                               3.827577
# Genre                               0.596394
# Gross_Collection in USD(Million)    3.427370
# Stars                              -0.004623
# dtype: float64

# %%
df3.sample()
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 1142   1143          768            108  1990      6.2         41       747
#
#       Votes  Genre  Gross_Collection in USD(Million)  Stars
# 1142  38202     32                             24.08    750

# %% [markdown]
# # Power transformation and scaling

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[-2.1654745 ,  0.90551541,  1.57641841, ...,  0.3704684 ,
#          2.17761493, -1.14055404],
#        [-2.1553844 ,  1.07700804,  2.72394158, ..., -1.31890152,
#          1.88081704, -0.71061056],
#        [-2.14624282,  0.6483941 ,  1.18656854, ...,  1.57094843,
#         -1.47154547,  1.13925576],
#        ...,
#        [ 1.55269283, -1.74617326, -1.81775158, ...,  1.14860241,
#         -1.47154547, -0.68193882],
#        [ 1.55419608, -0.87413985,  0.60538871, ...,  0.3704684 ,
#         -1.47154547,  1.46442176],
#        [ 1.55569909,  0.46807301,  0.93005447, ...,  0.62123665,
#         -1.47154547, -1.86076408]])

# %% [markdown]
# # Standard Scaling

# %%
x=df3.drop(["Votes"],axis=1)  
y=df3["Votes"]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_scale = scaler.fit_transform(x)
x=pd.DataFrame(x)
x
# Out:
#       Sl No  Movie Name1  Time Duration  Year  Ratings  Metascore  Director  \
# 0         1         1332            152  2008      9.0         84       136
# 1         2         1437            201  2003      9.0         94       617
# 2         3         1179            140  2023      8.9         86       920
# 3         4          614            148  2010      8.8         74       136
# 4         5         1436            178  2001      8.8         92       617
# ...     ...          ...            ...   ...      ...        ...       ...
# 1767   1768          999            109  2021      1.9          0       635
# 1768   1769          997            160  2018      1.9          0       655
# 1769   1770           87             85  2015      1.6          0       954
# 1770   1771          400            125  2021      1.5          0       449
# 1771   1772         1075            133  2020      1.2          0       495
#
#       Genre  Gross_Collection in USD(Million)  Stars
# ...

# %% [markdown]
# # using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x_scale,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#    VIF values                          Features
# 0    9.077018                             Sl No
# 1    1.005920                       Movie Name1
# 2    1.329610                     Time Duration
# 3    1.093416                              Year
# 4    8.697583                           Ratings
# 5    1.409710                         Metascore
# 6    1.009784                          Director
# 7    1.075384                             Genre
# 8    1.220793  Gross_Collection in USD(Million)
# 9    1.007848                             Stars

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(x_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(x_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(7))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
import xgboost as xgb
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1187, 7)
# Training target vector size: (1187,)
# Test feature matrix size: (585, 7)
# Test target vector size: (585,)

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(x_scale, y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.6917498298761889 on Random_state 360

# %% [markdown]
# # Linear Regression Base Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_scale, y, random_state=221, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual:'+'\033[0m\n',Y_test)
# Out:
# Predicted:
#  [ 3.37431129e+05  7.20876050e+04  1.03513939e+05  1.16357608e+05
#   1.37709942e+05  1.66794337e+05  3.16197025e+05  1.11502218e+05
#   1.79217927e+05  3.55043523e+05  2.05210765e+05 -4.87209602e+04
#   8.34572595e+05  5.74168222e+04  9.30580276e+04  7.16051149e+04
#   2.52427738e+05  2.85305528e+05  3.34750326e+05  2.18669572e+05
#   7.80649255e+04  4.95222590e+04  2.43724194e+05  8.67192343e+04
#   4.70935397e+05  5.89815561e+04  6.11956800e+04  9.75213047e+04
#   3.74311761e+05  4.69729088e+05  1.44737100e+05  1.59074607e+05
#   1.90860525e+05  4.73982803e+05  1.65141288e+05  4.25338121e+05
#   2.69057190e+04  1.56558841e+05  1.17884545e+05  2.87857493e+04
#   3.82795003e+05  6.75475646e+04  1.04064402e+05  1.60399173e+05
#   1.51139973e+05  2.23713030e+05  1.71066027e+05  3.83307048e+04
#   3.02501891e+05  1.55382845e+05  2.25874860e+05  1.72270190e+05
#   4.03293976e+03  2.34244666e+05  1.55431197e+05 -7.37294174e+02
# ...

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 86850.41727982037
# Mean squared error : 20123384178.186237
# Root Mean Squared Error: 141856.91445321316
#
#
#  R2 Score :
# 0.6373713891822561

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, x_scale, y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -9.105077941530126

# %% [markdown]
# # Applying other ML Models

# %%
from sklearn.ensemble import BaggingRegressor

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 63813.571863247846
# Mean squared error : 10049160960.603054
# Root Mean Squared Error: 100245.50344331189
#
#
#  R2 Score :
# 0.8189115087820262
# ...
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 63210.39172649572
# Mean squared error : 9749312928.208473
# Root Mean Squared Error: 98738.60910610638
#
#
#  R2 Score :
# 0.8243148482243825
# ...
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 89028.81367521368
# Mean squared error : 22575519430.167522
# Root Mean Squared Error: 150251.5205585871
#
#
#  R2 Score :
# 0.5931832748924588
# ...
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 115775.15721673975
# Mean squared error : 23655185253.34529
# Root Mean Squared Error: 153802.42278112945
#
#
#  R2 Score :
# 0.5737274162685024
# ...
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 58682.432107173605
# Mean squared error : 7767512940.049876
# ...

# %%
# Cross Validation
model = [rf,XT,dtc,adb,gradb]

for m in model:
    score = cross_val_score(m, x_scale, y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.532522759993193
# ...
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.5512024661115456
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -0.055752472755967133
# ...
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : -0.8815162958740373
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.5912862808418522
# ...

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[200,400,500,600],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[4,6,8,10],
              'eta' : [0.001, 0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 1/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=-0.199 total time=   0.1s
# [CV 2/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 2/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=-0.096 total time=   0.1s
# [CV 3/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 3/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=-0.328 total time=   0.1s
# [CV 4/5; 1/288] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200
# [CV 4/5; 1/288] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=200;, score=-0.170 total time=   0.1s
# ...

# %%
GCV.best_params_
# Out:
# {'booster': 'gbtree',
#  'eta': 0.1,
#  'gamma': 0.0,
#  'max_depth': 4,
#  'n_estimators': 400}

# %% [markdown]
# # Final Regression Model

# %%
Final_mod =  XGBRegressor(n_estimators=100 , booster= 'dart', eta= 0.1, max_depth= 10, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 64770.42688969017
# Mean squared error : 10765475136.590021
# Root Mean Squared Error: 103756.80766383486
#
#
#  R2 Score of Final Model :
# 0.8060033412368881

# %%
plt.figure(figsize=(15,8))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' Actual Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('Actual Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  Actual Values Vs Predicted Value plot :

# %% [markdown]
# # Final Regression Saving Model

# %%
import joblib
joblib.dump(Final_mod,'Votes_Final.pkl')
# Out:
# ['Votes_Final.pkl']

# %% [markdown]
# # Prediction According Final Regression Model

# %%
# Loading the saved model
Model = joblib.load("Votes_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test)
predicted = np.array(Model.predict(X_test))
df_Predicted = pd.DataFrame({"Actual Values":actual,"Predicted Values":predicted},index= range(len(actual)))
df_Predicted
# Out:
#      Actual Values  Predicted Values
# 0           282075      3.012433e+05
# 1            27068      5.077235e+04
# 2            35241      5.066069e+04
# 3            37195      6.651787e+04
# 4           160570      1.576765e+05
# ..             ...               ...
# 580         630867      1.015906e+06
# 581         137439      9.089241e+04
# 582          46816      4.451040e+04
# 583         121904      4.841417e+04
# 584         136273      7.410288e+04
#
# [585 rows x 2 columns]

# %% [markdown]
# # Machine Learning Model Building For Gross_Collection in USD(Million)

# %% [markdown]
# # Standard Scaling

# %%
X = df3.drop(['Gross_Collection in USD(Million)'], axis =1)
Y = df3['Gross_Collection in USD(Million)']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1187, 10)
# Training target vector size: (1187,)
# Test feature matrix size: (585, 10)
# Test target vector size: (585,)

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.6110090252592444 on Random_state 432

# %% [markdown]
# # Linear Regression Base Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=34, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted :'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual :'+'\033[0m\n',Y_test)
# Out:
# Predicted :
#  [ 5.56949570e+01  3.56129836e+01  6.51017039e+01  6.82392749e+01
#   1.70903812e+02  9.05699602e+01  7.67168882e+01  3.92044432e+01
#   5.29450730e+01  1.53630751e+02  8.40202475e+00  3.70174644e+01
#   2.68506685e+00  2.51745996e+01  2.38378630e+01  1.14497838e+02
#   5.41244541e+01  3.30219611e+01  6.98977806e+01 -8.10480072e+00
#   2.15600182e+01  4.38429205e+01  8.70592550e+01  5.86130121e+01
#   2.30716333e+01  9.03437297e+01  3.10419195e+00  1.26504729e+02
#   1.71297779e+01  5.36341338e+00  4.46652957e+01  7.19224519e+01
#   6.90478301e+01  5.61612745e+01  3.81843476e+01  5.89951312e+00
#   7.70154295e+01  3.90292923e+01  6.74073837e+01  3.16427334e+02
#   3.15073504e+01  3.77552242e+01  5.41561098e+01  1.00181563e+01
#   6.84045979e+01  2.72734652e+02  5.75628605e+01  1.32952651e+02
#   1.55572990e+00  9.62499603e+01  7.47488955e+01  1.58256609e+02
#   7.55765325e+01  4.56558305e+01  5.29433285e+01  2.35694948e+01
# ...

# %% [markdown]
# # Linear Regression Evaluation Matrix

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 38.46053279888802
# Mean squared error : 4167.309633255067
# Root Mean Squared Error: 64.55470264244943
#
#
#  R2 Score :
# 0.5403487528929992

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv =3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -0.938596668673628

# %% [markdown]
# # Applying other ML Models

# %%
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
xgb=XGBRegressor()
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 32.07830495726496
# Mean squared error : 3349.0998089396594
# Root Mean Squared Error: 57.87140752512988
#
#
#  R2 Score :
# 0.6305967064265152
# ...
#
#
#  Error of  ExtraTreesRegressor() :
# Mean absolute error : 31.550544102564107
# Mean squared error : 3149.833015794718
# Root Mean Squared Error: 56.12337316835757
#
#
#  R2 Score :
# 0.6525756900002753
# ...
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 43.94847863247864
# Mean squared error : 7421.422617435898
# Root Mean Squared Error: 86.1476791181045
#
#
#  R2 Score :
# 0.18142243758643206
# ...
#
#
#  Error of  AdaBoostRegressor() :
# Mean absolute error : 53.20642317008231
# Mean squared error : 5172.992007182273
# Root Mean Squared Error: 71.92351498072291
#
#
#  R2 Score :
# 0.42942271234148455
# ...
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 31.877331523244983
# Mean squared error : 3622.024607576766
# ...

# %%
# Cross Validation
model = [rf,XT,dtc,adb,gradb,xgb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.5843390150768187
# ...
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.5705714871899641
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.2149104170046967
# ...
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.036118119505169674
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.5989254779697425
# ...
#
#
# Cross Validation Score : XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
# ...

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[50,75,100],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[4,6,8,10],
              'eta' : [0.001, 0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV 1/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 1/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-0.306 total time=   0.0s
# [CV 2/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 2/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-0.307 total time=   0.0s
# [CV 3/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 3/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-0.354 total time=   0.0s
# [CV 4/5; 1/216] START booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50
# [CV 4/5; 1/216] END booster=gbtree, eta=0.001, gamma=0.0, max_depth=4, n_estimators=50;, score=-0.283 total time=   0.1s
# ...

# %%
GCV.best_params_
# Out:
# {'booster': 'dart',
#  'eta': 0.1,
#  'gamma': 0.1,
#  'max_depth': 4,
#  'n_estimators': 100}

# %% [markdown]
# # Final Regression Model For Gross_Collection in USD(Million)

# %%
Final_mod =  XGBRegressor(n_estimators=100 , booster= 'dart', eta= 0.1, max_depth= 8, gamma= 0.0 )
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 33.78708329904589
# Mean squared error : 4166.335136785596
# Root Mean Squared Error: 64.54715436628942
#
#
#  R2 Score of Final Model :
# 0.5404562391507803

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('Actual Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %% [markdown]
# # Saving  Final Regression Model For Gross_Collection in USD(Million)

# %%
import joblib
joblib.dump(Final_mod,'Gross_Collection in USD(Million)_Final.pkl')
# Out:
# ['Gross_Collection in USD(Million)_Final.pkl']

# %% [markdown]
# # Prediction According Final Regression Model For Gross_Collection in USD (Million)

# %%
# Loading the saved model
Model = joblib.load("Gross_Collection in USD(Million)_Final.pkl")

# prediction  DataFrame
actual = np.array(Y_test)
predicted = np.array(Model.predict(X_test))
df_Predicted = pd.DataFrame({"Actual Values":actual,"Predicted Values":predicted},index= range(len(actual)))
df_Predicted
# Out:
#      Actual Values  Predicted Values
# 0            25.05         58.388863
# 1            16.52         42.189148
# 2            79.96        107.976112
# 3             0.00         31.173914
# 4            48.07        162.026886
# ..             ...               ...
# 580           0.00         -1.349134
# 581          31.45          9.254107
# 582           0.00         15.373273
# 583          33.33         44.324059
# 584          34.71         34.360516
#
# [585 rows x 2 columns]
